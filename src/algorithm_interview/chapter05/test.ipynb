# %%
import collections

a = [1,2,3,5,2,'안녕']
a.remove(2)

# %%
a
# Out:
# [1, 3, 5, 2, '안녕']

# %%
a = {'key1': 'value1', 'key2': 'value2'}
a
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
a['key3'] = 'value3'
a
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
a['key1']
# Out:
# 'value1'

# %%
try:
    print(a['key4'])
except KeyError:
    print("존재하지 않는 키")
# Out:
# 존재하지 않는 키

# %%
del a['key4']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 del a['key4']
#
# KeyError: 'key4'

# %%
'key4' in a
# Out:
# False

# %%
if 'key4' in a:
    print('존재하는 키')
else:
    print('존재하지 않는 키')
# Out:
# 존재하지 않는 키

# %%
for k,v in a.items():
    print(k, v)
# Out:
# key1 value1
# key2 value2
# key3 value3

# %%
a = collections.defaultdict(int)
a['A'] = 5
a['B'] = 4
a
# Out:
# defaultdict(int, {'A': 5, 'B': 4})

# %%
a['C'] = 1
a
# Out:
# defaultdict(int, {'A': 5, 'B': 4, 'C': 1})

# %%
a['C'] += 1
a
# Out:
# defaultdict(int, {'A': 5, 'B': 4, 'C': 2})

# %%
a = [1,2,3,4,5,5,5,6,6]
b = collections.Counter(a)
b
# Out:
# Counter({1: 1, 2: 1, 3: 1, 4: 1, 5: 3, 6: 2})

# %%
type(b)
# Out:
# collections.Counter

# %%
b.most_common(2)
# Out:
# [(5, 3), (6, 2)]

# %%
x = dict()

# %%
x = collections.OrderedDict({'banana': 3, 'apple': 4, 'pear': 1, 'orange': 2})

# %%
x
# Out:
# OrderedDict([('banana', 3), ('apple', 4), ('pear', 1), ('orange', 2)])

# %%
x['avocado'] = 5
x
# Out:
# OrderedDict([('banana', 3),
#              ('apple', 4),
#              ('pear', 1),
#              ('orange', 2),
#              ('avocado', 5)])

# %%
type(x)
# Out:
# collections.OrderedDict
